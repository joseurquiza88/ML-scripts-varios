# %%
# Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization
#import seaborn as sns # for statistical data visualization
# Library
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np
import scipy.stats
from sklearn.metrics import mean_squared_error
from math import sqrt
import os
from os import listdir
from datetime import datetime
import pandas as pd
print("librerias ok")
# ubicacion de los archivos
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import seaborn as sns
# %matplotlib inline
# Out:
# librerias ok

# %%
data = pd.read_csv("D:/Josefina/Proyectos/ProyectoChile/dataset/proceed/merge_superf_sat/02_data_proceed_OHG.csv")
data.info() #Devuelve información número de filas, número de columnas, índices, tipo de objeto de cada columna
data_satelital
#--- Fromato date
data["date"] = data["date"].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))

# #Seteamos con index a la columna date_hour
data.set_index('date', inplace = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 46 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1114 non-null   int64
#  1   date           1114 non-null   object
#  2   AOD_470        1114 non-null   float64
#  3   AOD_550        1114 non-null   float64
#  4   PM25           1114 non-null   float64
#  5   temperatura    1114 non-null   float64
#  6   humedad        1114 non-null   float64
#  7   dirViento      1114 non-null   float64
#  8   velViento      1114 non-null   float64
#  9   estacion.x     1114 non-null   object
#  10  year           1114 non-null   int64
#  11  blh_mean       1114 non-null   float64
#  12  blh_min        1114 non-null   float64
#  13  blh_max        1114 non-null   float64
#  14  blh_sd         1114 non-null   float64
#  15  blh_mean_subt  1114 non-null   float64
#  16  sp_mean        1114 non-null   float64
# ...

# %%
print("---------           INFO SATELITAL           ---------    ")
print(data.describe())# Esta info tiene datos de 2015-2016
# Out:
# ---------           INFO SATELITAL           ---------
#         Unnamed: 0      AOD_470      AOD_550         PM25  temperatura  \
# count  1114.000000  1114.000000  1114.000000  1114.000000  1114.000000
# mean    557.500000     0.151894     0.109276    25.894037    17.376082
# std     321.728405     0.097363     0.071054    15.045240     5.218670
# min       1.000000     0.007250     0.005250     4.000010     3.305558
# 25%     279.250000     0.091656     0.065750    15.000000    13.438451
# 50%     557.500000     0.132375     0.094750    21.000000    18.106417
# 75%     835.750000     0.184625     0.132750    32.000000    21.668396
# max    1114.000000     0.940500     0.694000    88.000000    27.593050
#
#            humedad    dirViento    velViento         year     blh_mean  ...  \
# count  1114.000000  1114.000000  1114.000000  1114.000000  1114.000000  ...
# mean     53.607927     1.095488     1.095488  2017.047576   374.142109  ...
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'AOD_470', 'AOD_550', 'PM25', 'temperatura', 'humedad',
#        'dirViento', 'velViento', 'estacion.x', 'year', 'blh_mean', 'blh_min',
#        'blh_max', 'blh_sd', 'blh_mean_subt', 'sp_mean', 'sp_min', 'sp_max',
#        'sp_sd', 'sp_mean_subt', 'd2m_mean', 'd2m_min', 'd2m_max', 'd2m_sd',
#        'd2m_mean_subt', 't2m_mean', 't2m_min', 't2m_max', 't2m_sd',
#        't2m_mean_subt', 'v10_mean', 'v10_min', 'v10_max', 'v10_sd',
#        'v10_mean_subt', 'u10_mean', 'u10_min', 'u10_max', 'u10_sd',
#        'u10_mean_subt', 'tp_mean', 'tp_min', 'tp_max', 'tp_sd',
#        'tp_mean_subt'],
#       dtype='object')

# %%
#Hacemos un corplot con todas las variables satelitales y de superficie
#Valores medios

data_mean = data[['AOD_470','AOD_550', 'PM25', 'temperatura', 'humedad','dirViento', 'velViento',"blh_mean",
                           "d2m_mean","sp_mean","t2m_mean","tp_mean","u10_mean","v10_mean"]]
corr_merge = data_mean.corr()
fig,ax=plt.subplots(1,1,figsize=(12,8))
ax = sns.heatmap(corr_merge,  vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')

# %%
# Valores minimos
data_min = data[['AOD_550', 'PM25', 'temperatura', 'humedad','dirViento', 'velViento',"blh_min",
                           "d2m_min","sp_min","t2m_min","tp_min","u10_min","v10_min"]]
corr_merge = data_min.corr()
fig,ax=plt.subplots(1,1,figsize=(12,8))
ax = sns.heatmap(corr_merge,  vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')

# %%
# Valores max
data_max = data[['AOD_550', 'PM25', 'temperatura', 'humedad','dirViento', 'velViento',
                 "blh_max","d2m_max","sp_max","t2m_max","tp_max","u10_max","v10_max"]]
corr_merge = data_max.corr()
fig,ax=plt.subplots(1,1,figsize=(12,8))
ax = sns.heatmap(corr_merge,  vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')

# %%
# Valores de la pasada del satelite
data_mean_subt = data[['AOD_550', 'PM25', 'temperatura', 'humedad','dirViento', 'velViento',
                 "blh_mean_subt","d2m_mean_subt","sp_mean_subt","t2m_mean_subt","tp_mean_subt","u10_mean_subt","v10_mean_subt"]]
corr_merge = data_mean_subt.corr()
fig,ax=plt.subplots(1,1,figsize=(12,8))
ax = sns.heatmap(corr_merge,  vmin = -1, vmax = +1, annot = True, cmap = 'coolwarm')

# %% [markdown]
# # Series temporales

# %%
#                               - - - - - - -  PRECIPITACIOENES  - - - - - - -
#Series temporales
#Generamos un plot con serie temporal de las concentraciones de PM2.5 con todos los datos
fig, ax = plt.subplots(ncols=1,nrows=2,  figsize=(16,8),dpi=500)
# Plot
data_mean_period = data['2015-10-14':'2024-07-01']
ax[0].plot(data.index, df_merge_dia.precipitaciones,c="#807dba",label="Estacion superficial")
ax[1].plot(data.index, df_merge_dia.tp,c="#3f007d",label="Satelite")

#Medias
media_estacion = df_merge_dia['precipitaciones'].mean()
media_sat = df_merge_dia['tp'].mean()
ax[0].axhline(y=media_estacion, color= "black",linewidth=1.5, alpha=0.6, linestyle = '-')
ax[1].axhline(y=media_sat, color= "black",linewidth=1.5, alpha=0.6, linestyle = '-')

#Texto
ax[0].text(data_mean_period.index[1],4, "Mean" +" "+ str(round(media_estacion,2)),ha="left", va="center",fontdict={'family': 'serif', 'color' : 'Black', 'size': 11})
ax[1].text(data_mean_period.index[1],4, "Mean" +" "+ str(round(media_sat,2)),ha="left", va="center",fontdict={'family': 'serif', 'color' : 'Black', 'size': 11})
ax[1].legend()
ax[0].legend()
# titulo
ax[0].set_xlabel('Day')
ax[0].set_ylabel('Precipitaciones (mm)')
ax[1].set_xlabel('Day')
ax[1].set_ylabel('Precipitaciones (mm)')
ax[0].set_title('Serie temporal 2015-2023 Precipitaciones (mm). Estacion PM2.5 vs Satelite ERA')
plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# SETAMOS EJES

ax[0].yaxis.set_ticks(np.arange(0,5, 1)) 
ax[0].set_ylim(0,4.5) 

ax[1].yaxis.set_ticks(np.arange(0,5, 1)) 
ax[1].set_ylim(0,4.5
